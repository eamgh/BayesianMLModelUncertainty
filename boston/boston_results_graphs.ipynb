# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
x = [[14.31637303948725, 14.283654345068468, 14.439888302740357, 14.771709142697839, 14.40971121718676, 14.497521345870478, 14.579895147876778, 14.708429861746918, 15.36524062508153, 14.390687889190943],
     [13.807534603917462, 14.63218835829437, 14.652291211369075, 15.011912679371466, 14.5939058031617, 14.524496093845151, 13.687061055798717, 14.625643455361024, 13.984130882340148, 15.078897647672902],
     [12.04287712853633, 13.079917824727834, 13.067934144956405, 13.070224683381483, 13.752907960099032, 12.41150981060203, 14.07980512189814, 13.590658753592747, 13.411820546259818, 13.319857644477189],
     [44.52278503230518, 46.168694284068685, 43.49013511563798, 45.0738055232382, 44.83342784093254, 48.690900532866806, 44.941355432522094, 45.165405921749866, 46.44723592214024, 46.97161112231603]]
df = pd.DataFrame(x, index=['Efron', 'Rubin', 'Proper B. w=0', 'Proper B. w=0.25'])

df.T.boxplot(showfliers=False)
plt.subplots_adjust(bottom=0.23)
plt.xticks(rotation=45)
plt.show()

# %%
x = [[14.31637303948725, 14.283654345068468, 14.439888302740357, 14.771709142697839, 14.40971121718676, 14.497521345870478, 14.579895147876778, 14.708429861746918, 15.36524062508153, 14.390687889190943],
     [13.807534603917462, 14.63218835829437, 14.652291211369075, 15.011912679371466, 14.5939058031617, 14.524496093845151, 13.687061055798717, 14.625643455361024, 13.984130882340148, 15.078897647672902],
     [12.04287712853633, 13.079917824727834, 13.067934144956405, 13.070224683381483, 13.752907960099032, 12.41150981060203, 14.07980512189814, 13.590658753592747, 13.411820546259818, 13.319857644477189]]
df = pd.DataFrame(x, index=['Efron', 'Rubin', 'Proper B. w=0'])

df.T.boxplot(showfliers=False)
plt.subplots_adjust(bottom=0.23)
plt.xticks(rotation=65)

# Increase the font size of tick labels
plt.tick_params(axis='both', which='major', labelsize=12)
plt.show()

# %%
import numpy as np

# %%
np.mean([14.31637303948725, 14.283654345068468, 14.439888302740357, 14.771709142697839, 14.40971121718676, 14.497521345870478, 14.579895147876778, 14.708429861746918, 15.36524062508153, 14.390687889190943])
# Out:
# 14.57631109169473

# %%
np.mean([13.807534603917462, 14.63218835829437, 14.652291211369075, 15.011912679371466, 14.5939058031617, 14.524496093845151, 13.687061055798717, 14.625643455361024, 13.984130882340148, 15.078897647672902])
# Out:
# 14.459806179113201

# %%
np.mean([12.04287712853633, 13.079917824727834, 13.067934144956405, 13.070224683381483, 13.752907960099032, 12.41150981060203, 14.07980512189814, 13.590658753592747, 13.411820546259818, 13.319857644477189])
# Out:
# 13.182751361853102

# %%
np.mean([44.52278503230518, 46.168694284068685, 43.49013511563798, 45.0738055232382, 44.83342784093254, 48.690900532866806, 44.941355432522094, 45.165405921749866, 46.44723592214024, 46.97161112231603])
# Out:
# 45.630535672777754

# %%
np.mean([33.15743582212857,
30.625573382899113,
28.98337991269878,
30.491878765919594,
28.636248426934014,
])
# Out:
# 30.37890326211601

# %%
print(np.around([33.15743582212857,
30.625573382899113,
28.98337991269878,
30.491878765919594,
28.636248426934014,
], decimals=5, out=None))
# Out:
# [33.15744 30.62557 28.98338 30.49188 28.63625]
